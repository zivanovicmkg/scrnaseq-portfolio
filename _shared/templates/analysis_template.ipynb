# %% [markdown]
# # Project NN — {{TITLE}}
#
# **Tool:** Scanpy | **Dataset:** {{accession}} | **Reference:** {{citation}}
#
# ## Goals
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('../../_shared/scripts')

import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

import portfolio_utils as pu
pu.setup_plotting()

DATA_DIR    = Path('../data')
FIG_DIR     = Path('../figures')
RESULTS_DIR = Path('../results')
for d in (DATA_DIR, FIG_DIR, RESULTS_DIR):
    d.mkdir(parents=True, exist_ok=True)

sc.logging.print_header()

# %% [markdown]
# ## 2. Load data

# %%
# adata = sc.read_h5ad(DATA_DIR / 'raw.h5ad')
# adata

# %% [markdown]
# ## 3. Quality control

# %%
# adata.var['mt']   = adata.var_names.str.startswith('MT-')
# adata.var['ribo'] = adata.var_names.str.startswith(('RPS', 'RPL'))
# sc.pp.calculate_qc_metrics(adata, qc_vars=['mt','ribo'], inplace=True, log1p=False)
# sc.pl.violin(adata, ['n_genes_by_counts','total_counts','pct_counts_mt'], jitter=0.4, multi_panel=True)

# %% [markdown]
# ## 4. Normalization & feature selection

# %%
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)
# sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat')

# %% [markdown]
# ## 5. Dimensionality reduction & clustering

# %%
# sc.pp.scale(adata, max_value=10)
# sc.tl.pca(adata, n_comps=50)
# sc.pp.neighbors(adata, n_neighbors=15, n_pcs=30)
# sc.tl.umap(adata)
# sc.tl.leiden(adata, resolution=0.6)

# %% [markdown]
# ## 6. Annotation & marker genes

# %%
# sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
# sc.pl.rank_genes_groups(adata, n_genes=10, sharey=False)

# %% [markdown]
# ## 7. Hero figure (Upwork thumbnail)

# %%
# fig = sc.pl.umap(adata, color='leiden', return_fig=True, frameon=False, title='')
# pu.save_figure(fig, 'hero_umap', out_dir=FIG_DIR)

# %% [markdown]
# ## 8. Export results

# %%
# adata.write_h5ad(RESULTS_DIR / 'processed.h5ad')
# print(pu.quick_qc_summary(adata))
